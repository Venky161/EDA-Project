# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Cleaned_set1.csv")

# %%
df.head()
# Out:
#    Brand                              Model  Availability  \
# 0  Tesla             Model Y Long Range AWD  Discontinued
# 1  Tesla             Model 3 Long Range AWD  Discontinued
# 2    Kia                     EV3 Long Range     Available
# 3  Tesla  Model 3 RWD (Highland CATL LFP64)     Available
# 4  Tesla              Model Y RWD (Juniper)     Available
#
#                Availability_Status  Range(in_mile)  Efficiency(Wh/mile)  \
# 0  (February 2022 - February 2025)             275                273.0
# 1   (February 2022 - October 2023)             300                250.0
# 2      to order since October 2024             280                279.0
# 3          to order since May 2025             275                220.0
# 4     to order since February 2025             235                257.0
#
#    Weight_in_Kg  t_0_60_mph  Battery_Capacity(kWh)  Seating_Capacity  \
# 0        2054.0         5.0                   75.0                 7
# 1        1919.0         4.4                   75.0                 5
# 2        1885.0         7.7                   78.0                 5
# 3        1836.0         6.1                   60.5                 5
# 4        2003.0         5.9                   60.5                 5
#
#    Boot Space(in_Litres)  Price_Per_Range(in_£)  Model Price(in_£)
# 0                  971.0                  189.0              51990
# 1                  649.0                  170.0              50990
# 2                  485.0                  129.0              35995
# 3                  682.0                  145.0              39990
# 4                  971.0                  191.0              44990

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746 entries, 0 to 745
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Brand                  746 non-null    object
#  1   Model                  746 non-null    object
#  2   Availability           746 non-null    object
#  3   Availability_Status    746 non-null    object
#  4   Range(in_mile)         746 non-null    int64
#  5   Efficiency(Wh/mile)    746 non-null    float64
#  6   Weight_in_Kg           746 non-null    float64
#  7   t_0_60_mph             746 non-null    float64
#  8   Battery_Capacity(kWh)  746 non-null    float64
#  9   Seating_Capacity       746 non-null    int64
#  10  Boot Space(in_Litres)  746 non-null    float64
#  11  Price_Per_Range(in_£)  746 non-null    float64
#  12  Model Price(in_£)      746 non-null    int64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 75.9+ KB

# %%
df.groupby(by=['Brand','Model'])['Range(in_mile)'].mean()
# Out:
# Brand   Model
# Abarth  500e Convertible                           140.0
#         500e Hatchback                             140.0
#         500e Scorpionissima                        140.0
#         600e Scorpionissima                        170.0
#         600e Turismo                               170.0
#                                                    ...
# Volvo   XC40 Recharge Twin Motor (MY24)            235.0
#         XC40 Recharge Twin Pure Electric (MY22)    205.0
#         XC40 Recharge Twin Pure Electric (MY23)    215.0
# XPENG   G6 RWD Long Range                          300.0
#         G6 RWD Standard Range                      230.0
# Name: Range(in_mile), Length: 592, dtype: float64

# %% [markdown]
# ## Pivot Table

# %%
piv = pd.pivot_table(df, values=['Range(in_mile)','Seating_Capacity','Boot Space(in_Litres)'], index=['Brand',"Availability",'Availability_Status']).sample(n=10)

# %%
piv
# Out:
#                                                             Boot Space(in_Litres)  \
# Brand         Availability Availability_Status
# Tesla         Discontinued (October 2016 - June 2017)                  491.000000
# Kia           Available    to order since June 2025                    442.500000
# Hyundai       Discontinued (October 2018 - October 2019)               332.000000
# Mercedes-Benz Discontinued (December 2020 - December 2023)            1190.000000
#                            (June 2022 - November 2023)                 340.000000
# Audi          Available    to order since November 2024                575.000000
# Mercedes-Benz Discontinued (July 2022 - September 2023)                430.000000
# Toyota        Available    to order since August 2022                  452.000000
# Tesla         Discontinued (April 2016 - November 2016)                895.000000
# Nissan        Available    to order since August 2022                  450.333333
#
#                                                             Range(in_mile)  \
# Brand         Availability Availability_Status
# Tesla         Discontinued (October 2016 - June 2017)               245.00
# Kia           Available    to order since June 2025                 250.00
# Hyundai       Discontinued (October 2018 - October 2019)            240.00
# Mercedes-Benz Discontinued (December 2020 - December 2023)          190.00
#                            (June 2022 - November 2023)              260.00
# Audi          Available    to order since November 2024             296.25
# Mercedes-Benz Discontinued (July 2022 - September 2023)             300.00
# Toyota        Available    to order since August 2022               215.00
# Tesla         Discontinued (April 2016 - November 2016)             250.00
# Nissan        Available    to order since August 2022               245.00
#
#                                                             Seating_Capacity
# Brand         Availability Availability_Status
# Tesla         Discontinued (October 2016 - June 2017)                    7.0
# Kia           Available    to order since June 2025                      6.0
# Hyundai       Discontinued (October 2018 - October 2019)                 5.0
# Mercedes-Benz Discontinued (December 2020 - December 2023)               9.0
#                            (June 2022 - November 2023)                   5.0
# Audi          Available    to order since November 2024                  5.0
# Mercedes-Benz Discontinued (July 2022 - September 2023)                  5.0
# Toyota        Available    to order since August 2022                    5.0
# Tesla         Discontinued (April 2016 - November 2016)                  5.0
# Nissan        Available    to order since August 2022                    5.0

# %%
df['Boot Space(in_Litres)']
# Out:
# 0      971.0
# 1      649.0
# 2      485.0
# 3      682.0
# 4      971.0
#        ...
# 741    260.0
# 742    451.0
# 743    571.0
# 744    603.0
# 745    615.0
# Name: Boot Space(in_Litres), Length: 746, dtype: float64

# %%
df.describe()
# Out:
#        Range(in_mile)  Efficiency(Wh/mile)  Weight_in_Kg  t_0_60_mph  \
# count      746.000000           746.000000    746.000000  746.000000
# mean       229.262735           304.172922   2058.912869    7.058847
# std         68.285273            43.040962    373.114523    2.913198
# min         50.000000           176.000000   1009.000000    2.200000
# 25%        190.000000           274.000000   1806.500000    4.800000
# 50%        235.000000           296.000000   2117.000000    6.700000
# 75%        280.000000           325.000000   2306.500000    8.575000
# max        425.000000           527.000000   3085.000000   22.400000
#
#        Battery_Capacity(kWh)  Seating_Capacity  Boot Space(in_Litres)  \
# count             746.000000        746.000000             746.000000
# mean               69.589812          5.171582             513.714477
# std                21.931369          0.976253             203.220878
# min                14.500000          2.000000             151.000000
# 25%                52.000000          5.000000             386.250000
# 50%                74.000000          5.000000             491.000000
# 75%                84.925000          5.000000             578.000000
# max               118.000000          9.000000            2000.000000
#
#        Price_Per_Range(in_£)  Model Price(in_£)
# count             746.000000         746.000000
# mean              245.293566       56385.990617
# std               111.688846       34220.420047
# min                 0.000000           0.000000
# 25%               179.000000       34801.250000
# 50%               219.000000       48660.000000
# 75%               292.250000       68933.750000
# max              1138.000000      330000.000000

# %% [markdown]
# # Visualizations

# %% [markdown]
# ### 1. 🔋 Battery Capacity vs Range
